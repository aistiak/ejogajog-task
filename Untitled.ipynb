# %%
import requests 
  
# api-endpoint 
URL = "http://www.prothomalo.com"

# %%
r = requests.get(url = URL)

# %%
r
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup

# %%
data = BeautifulSoup(r.text)

# %%
data
# Out:
# <!DOCTYPE html>
# <html lang="bn"><head prefix="og: http://ogp.me/ns#">
# <!--turn off IE compatibility mode -->
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8"/>
# <!--<meta http-equiv="Content-Type" content="text/html; charset=utf-8"/>-->
# <meta content="width=device-width, minimum-scale=1, initial-scale=1, maximum-scale=1, user-scalable=0" name="viewport"/>
# <!-- Website SEO -->
# <title>Prothom Alo | Latest online bangla world news bd | Sports photo video live</title>
# ...

# %%
news_links = data.findAll('a',href=True, attrs={'class':'link_overlay'})

# %%
news_links
# Out:
# [<a class="link_overlay" href="/bangladesh/article/1640741/%E0%A6%B8%E0%A7%8B%E0%A6%AE%E0%A6%AC%E0%A6%BE%E0%A6%B0%E0%A7%87%E0%A6%B0-%E0%A6%AE%E0%A6%A7%E0%A7%8D%E0%A6%AF%E0%A7%87-%E0%A6%97%E0%A7%8D%E0%A6%B0%E0%A6%BE%E0%A6%AE%E0%A7%80%E0%A6%A3-%E0%A6%AB%E0%A7%8B%E0%A6%A8%E0%A6%95%E0%A7%87-%E0%A6%A6%E0%A6%BF%E0%A6%A4%E0%A7%87-%E0%A6%B9%E0%A6%AC%E0%A7%87-%E0%A7%A7%E0%A7%A6%E0%A7%A6%E0%A7%A6-%E0%A6%95%E0%A7%8B%E0%A6%9F%E0%A6%BF"></a>,
#  <a class="link_overlay" href="/bangladesh/article/1640749/%E0%A6%8F%E0%A6%95%E0%A7%81%E0%A6%B6%E0%A7%87-%E0%A6%AA%E0%A6%A6%E0%A6%95-%E0%A6%A4%E0%A7%81%E0%A6%B2%E0%A7%87-%E0%A6%A6%E0%A6%BF%E0%A6%B2%E0%A7%87%E0%A6%A8-%E0%A6%AA%E0%A7%8D%E0%A6%B0%E0%A6%A7%E0%A6%BE%E0%A6%A8%E0%A6%AE%E0%A6%A8%E0%A7%8D%E0%A6%A4%E0%A7%8D%E0%A6%B0%E0%A7%80"></a>,
# ...

# %%
t = "http://www.prothomalo.com/"+news_links[0]["href"]

# %%
hash(t)
# Out:
# -2472082482944764486

# %%
a_links = data.findAll('a',href=True)
all_links = []
for v in a_links:
    all_links.append("http://www.prothomalo.com"+v["href"])

# %%
# list(filter(lambda v : v["class"] == "link_overlay",links))
links
# Out:
# [<a href="/"><img alt="প্রথম আলো" height="46" src="//paloimages.prothom-alo.com/contents/themes/public/style/images/Prothom-Alo.png"/></a>,
#  <a class="static" href="/home">প্রচ্ছদ</a>,
#  <a class="dynamic" href="/bangladesh">বাংলাদেশ</a>,
#  <a class="dynamic" href="/international">আন্তর্জাতিক</a>,
#  <a class="dynamic" href="/economy">অর্থনীতি</a>,
#  <a class="dynamic" href="/opinion">মতামত</a>,
#  <a class="dynamic" href="/sports">খেলা</a>,
#  <a class="dynamic" href="/entertainment">বিনোদন</a>,
#  <a class="static" href="/features">ফিচার</a>,
#  <a class="dynamic" href="/technology">বিজ্ঞান ও প্রযুক্তি</a>,
#  <a class="dynamic" href="/life-style">জীবনযাপন</a>,
#  <a class="dynamic" href="/education">শিক্ষা</a>,
#  <a class="dynamic" href="/onnoalo">অন্য আলো</a>,
#  <a class="dynamic" href="/we-are">আমরা</a>,
#  <a class="dynamic" href="/pachmisheli">পাঁচমিশালি</a>,
#  <a class="dynamic" href="/special-supplement">বিশেষ সংখ্যা</a>,
# ...

# %%
t = {}

# %%
t[hash("arifi")] = "arifi"

# %%
t
# Out:
# {3401663149648140190: 'arif', -2554648011268575814: 'arifi'}

# %%
t.has("arif")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-bab71bedfb08> in <module>
# ----> 1 t.has("arif")
#
# AttributeError: 'dict' object has no attribute 'has'

# %%
"link_overlay" in links[60]["class"]
# Out:
# True

# %%
"a" in "a
"
# Out:
#   File "<ipython-input-111-f95302a2e586>", line 1
#     "a" in "a
#              ^
# SyntaxError: EOL while scanning string literal
